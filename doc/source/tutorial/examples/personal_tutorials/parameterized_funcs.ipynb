# %%
from matplotlib import pyplot as plt

# %%
plt.plot([1,2,3,4])
plt.ylabel("some number")
# Out:
# Text(0, 0.5, 'some number')

# %%
#Plot is versatile
plt.plot([1,2,3,4], [1,4,9,16])

# %% [markdown]
# Formatting exaple

# %%
plt.plot([1,2,3,4], [1,4,9,16],'ro')
plt.axis((0,6,0,20))
# Out:
# (0.0, 6.0, 0.0, 20.0)

# %%
#Scipy can use Numpy
import numpy as np

#Evenly sampled time at 200ms intervals
t = np.arange(0.,5.,0.2)

# red dashes, blue squares and green triangles
plt.plot(t,t,'r--',t,t**2,'bs',t,t**3,'g^')

# %%
# Plotting with keyword strings
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()

# %%
# Plotting with Categorical data
names = ['group_a', 'group_b', 'group_c']
values = [1, 10, 100]

plt.figure(figsize=(9, 3))

plt.subplot(131)
plt.bar(names, values)
plt.subplot(132)
plt.scatter(names, values)
plt.subplot(133)
plt.plot(names, values)
plt.suptitle('Categorical Plotting')
plt.show()

# %%
# Working with multiple figures
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure()
plt.subplot(211)
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')

plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
plt.show()

# %%
#Working with text
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, density=True, facecolor='g', alpha=0.75)


plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()

# %%
# Annotating Text
ax = plt.subplot()

t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2*np.pi*t)
line, = plt.plot(t, s, lw=2)

plt.annotate('local max', xy=(2, 1), xytext=(3, 1.5),
             arrowprops=dict(facecolor='black', shrink=0.05),
             )

plt.ylim(-2, 2)
plt.show()

# %%
#Logarithmic and other non-linear axis
# Fixing random state for reproducibility
np.random.seed(19680801)

# make up some data in the open interval (0, 1)
y = np.random.normal(loc=0.5, scale=0.4, size=1000)
y = y[(y > 0) & (y < 1)]
y.sort()
x = np.arange(len(y))

# plot with various axes scales
plt.figure()

# linear
plt.subplot(221)
plt.plot(x, y)
plt.yscale('linear')
plt.title('linear')
plt.grid(True)

# log
plt.subplot(222)
plt.plot(x, y)
plt.yscale('log')
plt.title('log')
plt.grid(True)

# symmetric log
plt.subplot(223)
plt.plot(x, y - y.mean())
plt.yscale('symlog', linthresh=0.01)
plt.title('symlog')
plt.grid(True)

# logit
plt.subplot(224)
plt.plot(x, y)
plt.yscale('logit')
plt.title('logit')
plt.grid(True)
# Adjust the subplot layout, because the logit one may take more space
# than usual, due to y-tick labels like "1 - 10^{-3}"
plt.subplots_adjust(top=0.92, bottom=0.08, left=0.10, right=0.95, hspace=0.25,
                    wspace=0.35)

plt.show()

# %%
#Preliminary Mathematics
y = np.random.normal(loc=0.5, scale=0.4, size=1000)
y = y[(y > 0) & (y < 1)]
y.sort()
x = np.arange(len(y))

plt.plot(x,y)

# %%
#Circle plotting answers https://stackoverflow.com/questions/32092899/plot-equation-showing-a-circle

# %% [markdown]
# Parameterization, defines motion on the curve. Motions on the curve  refers to the way that the point (x,y ) traces out the curve

# %%
def f(t):
    return np.sin(t)
def y(t):
    return np.cos(t)

t1 = np.arange(0.,0.5,0.01)
x = np.sin(t1)
y = np.cos(t1)
plt.plot(x,y)

# %% [markdown]
# Defining the Parametric Curve
# ***
# Equation 2.1 &emsp;&emsp;&emsp;&emsp;
#     $x(t) = sin(t) \ $ , $y(t) = cos(t)$

# %%
# https://stackoverflow.com/questions/25072488/how-to-draw-circle-by-data-with-matplotlib-python#:~:text=If%20you%27re%20looking%20to%20generate%20a%20circle%20from,%3E%3E%3E%20y%20%3D%20np.sin%20%28t%29%20%3E%3E%3E%20plt.plot%20%28x%2Cy%29
t = np.linspace(0,2*np.pi,100)
x = np.cos(t)
y = np.sin(t)
plt.plot(x,y)

# %% [markdown]
# Parameterization uses an independent parameter to  compute points on the curve.
# It gives the "motion" of a point on the curve
# Trig function as above is different from polynomial or rational function
# <br>
# $x(t)  =  \frac{2t}{(1 + t^2)} , \ y(t) = \frac{(1-t^2  )}{(1+t^2)}  \  \    2.2$

# %%
t = np.linspace(-(np.log(0)),np.log(0))
x = (2*t) / (1+t**2)

y = (1-t**2)/(1+t**2)
plt.plot(x,y)
# Out:
# /tmp/ipykernel_19421/4089543547.py:1: RuntimeWarning: divide by zero encountered in log
#   t = np.linspace(-(np.log(0)),np.log(0))
# /tmp/ipykernel_19421/4089543547.py:2: RuntimeWarning: invalid value encountered in divide
#   x = (2*t) / (1+t**2)
# /tmp/ipykernel_19421/4089543547.py:4: RuntimeWarning: invalid value encountered in divide
#   y = (1-t**2)/(1+t**2)
